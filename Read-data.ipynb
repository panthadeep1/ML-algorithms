# %%
##Author: panthadeep_b; 
#Date: 16Feb'25; Time: 12.47 IST
##WAP to implement linear regression

import sys
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from array import *
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import datasets

##Read file manually
fp = open("magic.csv");
attr = fp.readline(); ##Read the first line of attributes

data_matrix = [];
i = 0;
while(True):
    line = fp.readline();
    if(line == ""):
        break;
    else:
        rec = [str(j) for j in line.split(",")];
        data_matrix.insert(i, rec);
        i += 1;
        
#print("The data_matrix is:\n", data_matrix);

x = [row[0:3] for row in data_matrix];
y = [row[10] for row in data_matrix];

print("X is:", len(x));
print("Y is:", len(y));

x = pd.DataFrame(x); ##Convert x,y to DataFrame
y = pd.DataFrame(y);

x = x.to_numpy().reshape(len(x),3); ## Reshape for compatibility with scikit-learn
y = y.to_numpy().reshape(len(y),1);

print("X is:", x);##Display data
print("Y is:", y);
# Out:
# X is: 19020
# Y is: 19020
# X is: [['28.7967' '16.0021' '2.6449']
#  ['31.6036' '11.7235' '2.5185']
#  ['162.052' '136.031' '4.0612']
#  ...
#  ['75.4455' '47.5305' '3.4483']
#  ['120.5135' '76.9018' '3.9939']
#  ['187.1814' '53.0014' '3.2093']]
# Y is: [['g\n']
#  ['g\n']
#  ['g\n']
#  ...
#  ['h\n']
#  ['h\n']
#  ['h\n']]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc

data_set = pd.read_csv("housing.csv");
#print("The data is:\n", data_set);

x = data_set.iloc[:,[0,2]];
y = data_set.iloc[:,4];

print("X:\n",x);
print("Y:\n",y);

#x = x.to_numpy().reshape(len(x),2);
#y = y.to_numpy().reshape(len(y),1);

##Splitting the dataset into training and test set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.25, random_state=0);

#Train the model
model = LinearRegression();
model.fit(x_train,y_train);

#Intercept and Coefficient
print("Intercept: ", model.intercept_)
print("Coefficients:")
list(zip(x, model.coef_))

#Evaluate the model
y_pred = model.predict(x_test);
print("Prediction for test set: {}".format(y_pred))
# Out:
# X:
#       0.00632   2.31
# 0    0.02731   7.07
# 1    0.02729   7.07
# 2    0.03237   2.18
# 3    0.06905   2.18
# 4    0.02985   2.18
# ..       ...    ...
# 500  0.06263  11.93
# 501  0.04527  11.93
# 502  0.06076  11.93
# 503  0.10959  11.93
# 504  0.04741  11.93
#
# [505 rows x 2 columns]
# Y:
#  0      0.469
# 1      0.469
# 2      0.458
# 3      0.458
# 4      0.458
#        ...
# 500    0.573
# 501    0.573
# 502    0.573
# 503    0.573
# 504    0.573
# Name: 0.538, Length: 505, dtype: float64
# Intercept:  0.41873765525208184
# Coefficients:
# Prediction for test set: [0.45822561 0.45228649 0.64537317 0.43633165 0.63796155 0.51463089
#  0.53399416 0.67054868 0.64725551 0.64749411 0.65377606 0.46089958
#  0.46087798 0.49102102 0.46579394 0.44472757 0.64167291 0.42407893
#  0.65109911 0.48793543 0.5419033  0.66944007 0.64130501 0.51814313
#  0.49894047 0.69856242 0.51493433 0.65396436 0.4523527  0.4912823
#  0.64765889 0.53470376 0.71555038 0.55673073 0.54155316 0.63515788
# ...
