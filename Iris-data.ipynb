# %%
import pandas as pd
import numpy as np
import ssl
from ucimlrepo import fetch_ucirepo, list_available_datasets


print("This is jupyter-lab");
# Ignore ssl certificate verification
#ssl._create_default_https_context = ssl._create_unverified_context

# fetch dataset 
iris_data = fetch_ucirepo(id=53)

# access data
X = iris_data.data.features
y = iris_data.data.targets

#display features, target
print("X:", X);
print("y:", y);

# access metadata
print(iris_data.metadata.uci_id)
print(iris_data.metadata.num_instances)
print(iris_data.metadata.additional_info.summary)

# access variable info in tabular format
print(iris_data.variables)
# Out:
# This is jupyter-lab
# X:      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]
# y:               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# ...
